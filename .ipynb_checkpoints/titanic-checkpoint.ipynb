# %%
#import libray 
import numpy as np
import pandas as pd
from sklearn.selection_model import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression


#Load the Titanic Dataset
df=pd.read_csv("C:/Users/Admin/Desktop/Practicals/titanic.csv")

#Drop irrelavnt features
df=df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1,inplace=True)

#Handling missig values
imputer=SimpleImputer(strategy='most_frequent')
df['Age']=imputer.fit_transform(df[['Age']])
df['Embarked']=imputer.fit_transform(df[['Embarked']])

#Encoding categorical variables
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Embarked']=le.fit_transfomr(df['Embarked'])

#Splitting data into feature and target
X=df.drop('Survived',axis=1)
Y=df['Survived']

#Spliting data into training and testing sets
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=o.2,random_state=42)

#feature Selection(DT)
dt_model=DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train,Y_train)

selector_dt = SelectFromModel(dt_model, prefit=True)
X_train_dt = selector_dt.transform(X_train)
X_test_dt = selector_dt.transform(X_test)

#Feature Selection (RF)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

selector_rf = SelectFromModel(rf_model, prefit=True)
X_train_rf = selector_rf.transform(X_train)
X_test_rf = selector_rf.transform(X_test)

#Scaling
scaler_dt = StandardScaler()
X_train_dt = scaler_dt.fit_transform(X_train_dt)
X_test_dt = scaler_dt.transform(X_test_dt)

scaler_rf = StandardScaler()
X_train_rf = scaler_rf.fit_transform(X_train_rf)
X_test_rf = scaler_rf.transform(X_test_rf)

#Apply SVM model
svm_model = SVC()
svm_model.fit(X_train_rf, y_train)

svm_pred = svm_model.predict(X_test_rf)

print("===== SVM Results =====")
print("Accuracy:", accuracy_score(y_test, svm_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, svm_pred))
print("Classification Report:\n", classification_report(y_test, svm_pred))

#Apply LR model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train_dt, y_train)

lr_pred = lr_model.predict(X_test_dt)

print("\n===== Logistic Regression Results =====")
print("Accuracy:", accuracy_score(y_test, lr_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_pred))
print("Classification Report:\n", classification_report(y_test, lr_pred))
